# %%
import json
import requests
import pandas as pd
# insert your API key here
API_KEY = '21cdh0TAgTljZ1HdvVpmbLxuoo2'
# make API request
sopr = requests.get('https://api.glassnode.com/v1/metrics/indicators/sopr',
    params={'a': 'BTC', 'api_key': API_KEY})
addy_count = requests.get('https://api.glassnode.com/v1/metrics/addresses/count',
    params={'a': 'BTC', 'api_key': API_KEY, 's' : '2016-01-01'})
# convert to pandas dataframe
df = pd.read_json(res.text, convert_dates=['t'])
# Out:
#               t         v
# 0    2010-07-17  1.000000
# 1    2010-07-18  1.174760
# 2    2010-07-19  1.318536
# 3    2010-07-20  1.090517
# 4    2010-07-21  1.065532
# ...         ...       ...
# 4149 2021-11-25  1.010935
# 4150 2021-11-26  0.996968
# 4151 2021-11-27  0.999350
# 4152 2021-11-28  1.001206
# 4153 2021-11-29  1.003745
#
# [4154 rows x 2 columns]
